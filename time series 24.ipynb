# %% [markdown]
# <a href="https://colab.research.google.com/github/JuliusMananquil/Advance_-predictive_analiytics_-mananquil/blob/main/time%20series%2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


df=pd.read_csv("https://raw.githubusercontent.com/JAYFRANCISOLANGCO/TIME-SERIES/main/Electric_Production.csv")


df.head()
# Out:
#          DATE    Value
# 0  01-01-1985  72.5052
# 1  02-01-1985  70.6720
# 2  03-01-1985  62.4502
# 3  04-01-1985  57.4714
# 4  05-01-1985  55.3151

# %%
date_rng = pd.date_range(start='01-01-1985',end='05-01-1985',freq='D')


time_series_data = pd.Series(range(0,11))


df
# Out:
#            DATE     Value
# 0    01-01-1985   72.5052
# 1    02-01-1985   70.6720
# 2    03-01-1985   62.4502
# 3    04-01-1985   57.4714
# 4    05-01-1985   55.3151
# ..          ...       ...
# 392  09-01-2017   98.6154
# 393  10-01-2017   93.6137
# 394  11-01-2017   97.3359
# 395  12-01-2017  114.7212
# 396  01-01-2018  129.4048
#
# [397 rows x 2 columns]

# %%
import matplotlib.pyplot as plt


time_series_data_trend = time_series_data + 0.5 * pd.Series(range(0,11))


df
# Out:
#            DATE     Value
# 0    01-01-1985   72.5052
# 1    02-01-1985   70.6720
# 2    03-01-1985   62.4502
# 3    04-01-1985   57.4714
# 4    05-01-1985   55.3151
# ..          ...       ...
# 392  09-01-2017   98.6154
# 393  10-01-2017   93.6137
# 394  11-01-2017   97.3359
# 395  12-01-2017  114.7212
# 396  01-01-2018  129.4048
#
# [397 rows x 2 columns]

# %%
time_series_data_seasonal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f2bc52c0565e> in <cell line: 1>()
# ----> 1 time_series_data_seasonal
#
# NameError: name 'time_series_data_seasonal' is not defined

# %%
import numpy as np


time_series_data_cyclic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-eea916c44f26> in <cell line: 4>()
#       2
#       3
# ----> 4 time_series_data_cyclic
#
# NameError: name 'time_series_data_cyclic' is not defined

# %%
time_series_data_irregular
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-4caf94386117> in <cell line: 1>()
# ----> 1 time_series_data_irregular
#
# NameError: name 'time_series_data_irregular' is not defined
